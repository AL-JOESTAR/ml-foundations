# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('healthcare_dataset.csv', header = 0)

# %%
df.iloc[30:50, 2:12] # menampilkan data dari baris 30-50, dan dari kolom 2-12
# Out:
#     Gender Blood Type Medical Condition Date of Admission             Doctor  \
# 30    Male         B-            Asthma        2019-08-18        Jacob Huynh
# 31  Female         A+         Arthritis        2019-11-03   Kristina Frazier
# 32    Male        AB-         Arthritis        2023-05-18       John Hartman
# 33    Male        AB-            Cancer        2023-05-24     Heather Garcia
# 34  Female        AB+          Diabetes        2020-01-17         Lynn Young
# 35  Female        AB+            Asthma        2021-01-07       Emma Allison
# 36    Male        AB+          Diabetes        2019-10-14        Laura Myers
# 37  Female         B-      Hypertension        2021-12-19     Travis Parsons
# 38  Female         O-          Diabetes        2022-03-12  Christine Johnson
# 39  Female         B-           Obesity        2021-01-17       Emily Taylor
# 40  Female         B-      Hypertension        2021-09-15   William Reynolds
# ...

# %%
df.loc[30:50, ['Gender', 'Doctor']] # Menampilkan baris data dari 30-50 dan data Gender dan Doctor saja
# Out:
#     Gender             Doctor
# 30    Male        Jacob Huynh
# 31  Female   Kristina Frazier
# 32    Male       John Hartman
# 33    Male     Heather Garcia
# 34  Female         Lynn Young
# 35  Female       Emma Allison
# 36    Male        Laura Myers
# 37  Female     Travis Parsons
# 38  Female  Christine Johnson
# 39  Female       Emily Taylor
# 40  Female   William Reynolds
# 41    Male    Jennifer Carter
# 42  Female     Matthew Thomas
# 43  Female         Mary Logan
# 44  Female   Kristin Martinez
# 45    Male      Daniel Murphy
# 46  Female    Emily Patterson
# 47    Male      Heather Smith
# 48    Male         John Smith
# 49  Female      Cameron Young
# 50    Male       Vicki Nguyen

# %%
df.loc[df['Gender'] == ''Male]

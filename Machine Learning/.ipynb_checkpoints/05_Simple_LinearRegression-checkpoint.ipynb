# %% [markdown]
# Simple Linear Regression memodelkan hubungan antara sebuah response variable dengan sebuah explanatory variable sebagai suatu garis lurus (linear)
#
# Tujuan Project ini :
# Memprediksi Harga pizza jika diketahui diameter nya

# %% [markdown]
# ## Sample Dataset

# %%
import pandas as pd

pizza = {
    'diameter' : [6,8,10,14,18],
    'harga' : [7,9,13,17.5,18],
}

pizza_df = pd.DataFrame(pizza)
pizza_df
# Out:
#    diameter  harga
# 0         6    7.0
# 1         8    9.0
# 2        10   13.0
# 3        14   17.5
# 4        18   18.0

# %%
import matplotlib.pyplot as plt

pizza_df.plot(kind='scatter', x='diameter', y='harga')

plt.title('perbandingan Diameter dan Harga Pizza')
plt.xlabel('Diameter inch')
plt.ylabel('Harga $')
plt.xlim(0,25) # lim = jangkauan sumbu
plt.ylim(0,25)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Simple Linear Rgression Model

# %% [markdown]
# ### Penyesuaian DataSet

# %%
import numpy as np

X = np.array(pizza_df['diameter']) # Feature
y = np.array(pizza_df['harga']) # Target

print(f'X : {X}')
print(f'y : {y}')
# Out:
# X : [ 6  8 10 14 18]
# y : [ 7.   9.  13.  17.5 18. ]

# %%
X = X.reshape(-1, 1)
X.shape
# Out:
# (5, 1)

# %%
X
# Out:
# array([[ 6],
#        [ 8],
#        [10],
#        [14],
#        [18]])

# %% [markdown]
# ## Visualisasi Simple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
X_vis = np.array([0,25]).reshape(-1,1)
y_vis = model.predict(X_vis)

# %%
plt.scatter(X,y)
plt.plot(X_vis, y_vis, '-r')

plt.title('perbandingan diameter dan harga pizza')
plt.xlabel('diameter')
plt.ylabel('harga')
plt.xlim(0,25)
plt.ylim(0,25)
plt.grid(True)
plt.show()

# %% [markdown]
# Alpha : intercept
# beta : slope
#
# intercept merupakan titik pada sumbu y dimana garis linear yang terbentuk menabrak titik di sumbu y (nilai pada sumbu  y ketika x = 0)
# slope akan berpengarruh pada tingkat kemiringan

# %%
print(f'intercept: {model.intercept_}')
print(f'slope: {model.coef_}')
# Out:
# intercept: 1.965517241379315
# slope: [0.9762931]

# %% [markdown]
# ### Mencari nilai slope

# %%
print(f'X:\n{X}\n')
print(f'X flatten: {X.flatten()}\n')
print(f'y: {y}')
# Out:
# X:
# [[ 6]
#  [ 8]
#  [10]
#  [14]
#  [18]]
#
# X flatten: [ 6  8 10 14 18]
#
# y: [ 7.   9.  13.  17.5 18. ]

# %% [markdown]
# ### Variance

# %%
variance_x = np.var(X.flatten(), ddof=1) 
print(f'variance: {variance_x}')
# Out:
# variance: 23.2

# %% [markdown]
# ### Covariance

# %%
np.cov(X.flatten(), y)
# Out:
# array([[23.2 , 22.65],
#        [22.65, 24.3 ]])

# %%
covariance_xy = np.cov(X.flatten(), y)[0][1]
print(f'covariance: {covariance_xy}')
# Out:
# covariance: 22.650000000000002

# %% [markdown]
# ### Proses perhitungan Slope

# %%
slope = covariance_xy / variance_x
print(f'slope: {slope}')
# Out:
# slope: 0.976293103448276

# %% [markdown]
# ## Mencari Nilai intercept

# %%
intercept = np.mean(y) - slope * np.mean(X)
print(f'intercept: {intercept}')
# Out:
# intercept: 1.9655172413793096

# %% [markdown]
# # Prediksi Harga Pizza

# %%
diameter_pizza = np.array([12,20, 23]).reshape(-1,1) # Diamter yang mau di prediksi
diameter_pizza
# Out:
# array([[12],
#        [20],
#        [23]])

# %%
prediksi_harga = model.predict(diameter_pizza)
prediksi_harga
# Out:
# array([13.68103448, 21.49137931, 24.42025862])

# %% [markdown]
# ## Evaluasi Simple Linear Regression Model

# %%
X_train = np.array([6,8,10,14,18]).reshape(-1,1)
y_train = np.array([7,9,13,17.5,18])

X_test = np.array([8,9,11,16,12]).reshape(-1,1)
y_test = np.array([11,8.5,15,18,11])

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
r_squared = r2_score(y_test, y_pred)
print(f'r2 score : {r_squared}')
# Out:
# r2 score : 0.6620052929422553

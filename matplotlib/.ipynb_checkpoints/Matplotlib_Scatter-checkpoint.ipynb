# %%
import matplotlib.pyplot as plt
import numpy as np

dosen = ([11, 14,15,34,32,56,])
mahasiswa = ([204, 245,521,304,340,456,])

fig, ax = plt.subplots()
plt.scatter(dosen, mahasiswa)

ax.set_title('hubungan jumlah dosen dan mahasiswa ')
plt.show()

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.2 MB 1.2 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.2 MB 1.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/8.2 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.2 MB 1.2 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/8.2 MB 1.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.2 MB 1.5 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.2 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.2 MB 1.6 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.7/8.2 MB 1.7 MB/s eta 0:00:03
#    --------------------- ------------------ 4.5/8.2 MB 1.9 MB/s eta 0:00:03
# ...

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.10.9

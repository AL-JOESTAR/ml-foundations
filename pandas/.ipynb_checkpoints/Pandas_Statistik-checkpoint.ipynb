# %%
import pandas as pd

df = pd.DataFrame({
    "Mata Kuliah": [
        "kalkulus", "ips", "statistik", "fisika", "kimia",
        "biologi", "sejarah", "ekonomi", "bahasa", "informatika"
    ],
    "Nilai": [
        100, 90, 80, 85, 88,
        92, 75, 89, 95, 98
    ],
    "Predikat": [
        "A", "B", "C", "B", "B",
        "A", "C", "B", "A", "A"
    ]
})

statistik = df.describe()

print(statistik)

#Membuat menjadi statistik
# Out:
#             Nilai
# count   10.000000
# mean    89.200000
# std      7.757434
# min     75.000000
# 25%     85.750000
# 50%     89.500000
# 75%     94.250000
# max    100.000000

# %%
import pandas as pd

df = pd.DataFrame({
    "Mata Kuliah": [
        "kalkulus", "ips", "statistik", "fisika", "kimia",
        "biologi", "sejarah", "ekonomi", "bahasa", "informatika"
    ],
    "Nilai": [
        100, 90, 80, 85, 88,
        92, 75, 89, 95, 98
    ],
    "Predikat": [
        "A", "B", "C", "B", "B",
        "A", "C", "B", "A", "A"
    ]
})

Transpose = df.T

print(Transpose)

# Membuat menjadi transpose
# Out:
#                     0    1          2       3      4        5        6  \
# Mata Kuliah  kalkulus  ips  statistik  fisika  kimia  biologi  sejarah
# Nilai             100   90         80      85     88       92       75
# Predikat            A    B          C       B      B        A        C
#
#                    7       8            9
# Mata Kuliah  ekonomi  bahasa  informatika
# Nilai             89      95           98
# Predikat           B       A            A

# %%
import pandas as pd

df = pd.DataFrame({
    "Mata Kuliah": pd.Series(["kalkulus", "ips", "statistik"]),
    "Nilai" : pd.Series(["100", "90", "80"]),
    "Predikat" : pd.Series(["A", "B", "C"],)
})

print(df)

# Series = Data array 1 dimensi
# Out:
#   Mata Kuliah Nilai Predikat
# 0    kalkulus   100        A
# 1         ips    90        B
# 2   statistik    80        C

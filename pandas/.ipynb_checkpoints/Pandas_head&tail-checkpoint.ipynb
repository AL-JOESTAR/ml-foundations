# %%
import pandas as pd

import pandas as pd

df = pd.DataFrame({
    "Mata Kuliah": pd.Series([
        "kalkulus", "ips", "statistik", "fisika", "kimia",
        "biologi", "sejarah", "ekonomi", "bahasa", "informatika"
    ]),
    "Nilai": pd.Series([
        "100", "90", "80", "85", "88",
        "92", "75", "89", "95", "98"
    ]),
    "Predikat": pd.Series([
        "A", "B", "C", "B", "B",
        "A", "C", "B", "A", "A"
    ])
})


awal = df.head() # Melihat data dari awal

print(awal)
# Out:
#   Mata Kuliah Nilai Predikat
# 0    kalkulus   100        A
# 1         ips    90        B
# 2   statistik    80        C
# 3      fisika    85        B
# 4       kimia    88        B

# %%
import pandas as pd

import pandas as pd

df = pd.DataFrame({
    "Mata Kuliah": pd.Series([
        "kalkulus", "ips", "statistik", "fisika", "kimia",
        "biologi", "sejarah", "ekonomi", "bahasa", "informatika"
    ]),
    "Nilai": pd.Series([
        "100", "90", "80", "85", "88",
        "92", "75", "89", "95", "98"
    ]),
    "Predikat": pd.Series([
        "A", "B", "C", "B", "B",
        "A", "C", "B", "A", "A"
    ])
})


akhir = df.tail() # Melihat data dari akhir

print(akhir)
# Out:
#    Mata Kuliah Nilai Predikat
# 5      biologi    92        A
# 6      sejarah    75        C
# 7      ekonomi    89        B
# 8       bahasa    95        A
# 9  informatika    98        A
